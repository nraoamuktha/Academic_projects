# %% [markdown]
# <a href="https://colab.research.google.com/github/nraoamuktha/Academic_projects/blob/main/Optiver/Optiver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !kaggle competitions download -c optiver-trading-at-the-close
# Out:
# ...
#  87% 175M/201M [00:00<00:00, 257MB/s]
# 100% 201M/201M [00:00<00:00, 227MB/s]

# %%
# !unzip "/content/optiver-trading-at-the-close.zip" -d "/content/"
# Out:
# Archive:  /content/optiver-trading-at-the-close.zip
#   inflating: /content/example_test_files/revealed_targets.csv
#   inflating: /content/example_test_files/sample_submission.csv
#   inflating: /content/example_test_files/test.csv
#   inflating: /content/optiver2023/__init__.py
#   inflating: /content/optiver2023/competition.cpython-310-x86_64-linux-gnu.so
#   inflating: /content/public_timeseries_testing_util.py
#   inflating: /content/train.csv

# %%
import pandas as pd
import numpy as np

# %%
optiver_data = pd.read_csv("/content/train.csv")

# %%
optiver_data.head()
# Out:
#    stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0         0        0                  0      3180602.69
# 1         1        0                  0       166603.91
# 2         2        0                  0       302879.87
# 3         3        0                  0     11917682.27
# 4         4        0                  0       447549.96
#
#    imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                        1         0.999812   13380276.64        NaN
# 1                       -1         0.999896    1642214.25        NaN
# 2                       -1         0.999561    1819368.03        NaN
# 3                       -1         1.000171   18389745.62        NaN
# 4                       -1         0.999532   17860614.95        NaN
#
#    near_price  bid_price  bid_size  ask_price   ask_size  wap    target  \
# 0         NaN   0.999812  60651.50   1.000026    8493.03  1.0 -3.029704
# ...

# %%
optiver_data.describe()
# Out:
#            stock_id       date_id  seconds_in_bucket  imbalance_size  \
# count  5.237980e+06  5.237980e+06       5.237980e+06    5.237760e+06
# mean   9.928856e+01  2.415100e+02       2.700000e+02    5.715293e+06
# std    5.787176e+01  1.385319e+02       1.587451e+02    2.051591e+07
# min    0.000000e+00  0.000000e+00       0.000000e+00    0.000000e+00
# 25%    4.900000e+01  1.220000e+02       1.300000e+02    8.453415e+04
# 50%    9.900000e+01  2.420000e+02       2.700000e+02    1.113604e+06
# 75%    1.490000e+02  3.610000e+02       4.100000e+02    4.190951e+06
# max    1.990000e+02  4.800000e+02       5.400000e+02    2.982028e+09
#
#        imbalance_buy_sell_flag  reference_price  matched_size     far_price  \
# count             5.237980e+06     5.237760e+06  5.237760e+06  2.343638e+06
# mean             -1.189619e-02     9.999955e-01  4.510025e+07  1.001713e+00
# std               8.853374e-01     2.532497e-03  1.398413e+08  7.214705e-01
# ...

# %%
optiver_data.dropna(inplace=True)

# %%
optiver_data
# Out:
#          stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 5730            0        0                300            0.00
# 5731            1        0                300       242332.96
# 5732            2        0                300            0.00
# 5733            3        0                300      2914730.16
# 5734            4        0                300      3396923.02
# ...           ...      ...                ...             ...
# 5237975       195      480                540      2440722.89
# 5237976       196      480                540       349510.47
# 5237977       197      480                540            0.00
# 5237978       198      480                540      1000898.84
# 5237979       199      480                540      1884285.71
#
#          imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 5730                           0         1.000241   26670118.88   1.000241
# ...
